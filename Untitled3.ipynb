# %%
import random

var = random.randint(0, 15)

print(var)

if var == 3:
    print("Fizz")
elif var ==5:
    print("Buzz")
elif var ==15:
    print("FizzBuzz")
else:
    print(var)
# Out:
# 5
# Buzz
