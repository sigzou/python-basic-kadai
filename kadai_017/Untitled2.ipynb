# %%
class Human:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def check_adult(self):
        if self.age >=20:
            print("あなたは成人です")
        else:
            print("あなたは未成年です")

human1 = Human("Taro",15)
human2 = Human("Jiro",14)

human_lists = [human1, human2]

for human_list in human_lists:
    human_list.check_adult()
# Out:
# あなたは未成年です
# あなたは未成年です
